# %%
import tensorflow as tf
import os
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array

IMAGE_SIZE = 150
pathDataset = "./dataset"

CLASS = sorted(os.listdir(pathDataset + "/train"))
numClasses = len(CLASS)
print("Número de clases:", numClasses)

bestModel = "./bestModel.keras"
model = tf.keras.models.load_model(bestModel)
model.summary()

def preapImg(pathImg):
    img = load_img(pathImg, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    img_array = img_to_array(img).astype("float32")  # aseguramos dtype
    img_array = np.expand_dims(img_array, axis=0)
    img_array = (img_array / 127.5) - 1
    return img_array

def predecirImagen(pathImg):
    imForModel = preapImg(pathImg)
    predicciones = model.predict(imForModel, verbose=0)
    indice_predicho = np.argmax(predicciones)
    clase_predicha = CLASS[indice_predicho]
    prob = tf.nn.softmax(predicciones[0])
    confianza = tf.reduce_max(prob).numpy()
    print(f"Imagen: {pathImg}")
    print(f"Índice predicho: {indice_predicho}")
    print(f"Clase predicha: {clase_predicha}")
    print(f"Confianza: {confianza:.2f}")
    print("---------------------------")

predecirImagen("./ImgPrueba1.png")
predecirImagen("./ImgPrueba2.png")
# Out:
# Número de clases: 13
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)         │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 3, 3, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
