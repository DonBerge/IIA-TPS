# %% [markdown]
# ##### Dataset 1
# **Preprocesamiento**:
# - Auto-Orient: Applied
# - Resize: Stretch to 640x640
#
# **Contenido**:
# - Train: 6141 imágenes.
# - Valid: 3 imágenes.
# - Test: 2 imágenes.
#
# **Data augmentations**: No hay, pero se recomienda:
# - Outputs per training example: 3
# - Grayscale: Apply to 25% of images
# - Hue: Between -180° and +180°
# - Saturation: Between -15% and +15%
# - Brightness: Between -18% and +18%

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QgbgJ8ChSc0ml32j30r4")
project = rf.workspace("vgu-aeaes").project("naruto-hand-sign")
version = project.version(3)
dataset = version.download("multiclass", location="dataset", overwrite=True)

print("Path to dataset:", dataset.location)

# %% [markdown]
# ##### Dataset 2
# **Preprocesamiento**:
# Auto-Orient: Applied
# Resize: Stretch to 640x640
#
# **Contenido**:
# - Train: 75 imágenes.
# - Valid: 22 imágenes.
# - Test: 12 imágenes.
#
# **Data augmentation**:
# Ninguno

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QgbgJ8ChSc0ml32j30r4")
project = rf.workspace("taha-a1f4b").project("my-first-project-kaai3")
version = project.version(1)
dataset = version.download("multiclass", location="dataset", overwrite=True)

print("Path to dataset:", dataset.location)
